# %% [markdown]
# #                     CRIMES AGAINST WOMEN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("42_District_wise_crimes_committed_against_women_2001_2012.csv")
df
# Out:
#             STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0     ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1     ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2     ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3     ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4     ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
# ...              ...            ...   ...   ...                       ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012     0                         0
# 9013     LAKSHADWEEP          TOTAL  2012     0                         0
# 9014      PUDUCHERRY       KARAIKAL  2012     6                         2
# 9015      PUDUCHERRY     PUDUCHERRY  2012     7                        14
# 9016      PUDUCHERRY          TOTAL  2012    13                        16
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0  ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1  ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2  ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3  ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4  ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
# 2            14                                                112
# 3            17                                                126
# 4            12                                                109
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9017 entries, 0 to 9016
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9017 non-null   object
#  1   DISTRICT                                             9017 non-null   object
#  2   Year                                                 9017 non-null   int64
#  3   Rape                                                 9017 non-null   int64
#  4   Kidnapping and Abduction                             9017 non-null   int64
#  5   Dowry Deaths                                         9017 non-null   int64
#  6   Assault on women with intent to outrage her modesty  9017 non-null   int64
#  7   Insult to modesty of Women                           9017 non-null   int64
# ...

# %%
df.describe()
# Out:
#               Year         Rape  Kidnapping and Abduction  Dowry Deaths  \
# count  9017.000000  9017.000000               9017.000000   9017.000000
# mean   2006.629034    53.041366                 58.535433     20.228901
# std       3.463623   190.741450                246.937464     96.970466
# min    2001.000000     0.000000                  0.000000      0.000000
# 25%    2004.000000     8.000000                  6.000000      1.000000
# 50%    2007.000000    20.000000                 18.000000      5.000000
# 75%    2010.000000    41.000000                 42.000000     16.000000
# max    2012.000000  3425.000000               7910.000000   2322.000000
#
#        Assault on women with intent to outrage her modesty  \
# count                                        9017.000000
# mean                                          100.511257
# std                                           394.059436
# min                                             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# STATE/UT                                               0
# DISTRICT                                               0
# Year                                                   0
# Rape                                                   0
# Kidnapping and Abduction                               0
# Dowry Deaths                                           0
# Assault on women with intent to outrage her modesty    0
# Insult to modesty of Women                             0
# Cruelty by Husband or his Relatives                    0
# Importation of Girls                                   0
# dtype: int64

# %%
df.nunique()
# Out:
# STATE/UT                                                35
# DISTRICT                                               808
# Year                                                    12
# Rape                                                   420
# Kidnapping and Abduction                               460
# Dowry Deaths                                           256
# Assault on women with intent to outrage her modesty    553
# Insult to modesty of Women                             343
# Cruelty by Husband or his Relatives                    846
# Importation of Girls                                    37
# dtype: int64

# %%
list(df["STATE/UT"].unique())
# Out:
# ['ANDHRA PRADESH',
#  'ARUNACHAL PRADESH',
#  'ASSAM',
#  'BIHAR',
#  'CHHATTISGARH',
#  'GOA',
#  'GUJARAT',
#  'HARYANA',
#  'HIMACHAL PRADESH',
#  'JAMMU & KASHMIR',
#  'JHARKHAND',
#  'KARNATAKA',
#  'KERALA',
#  'MADHYA PRADESH',
#  'MAHARASHTRA',
#  'MANIPUR',
#  'MEGHALAYA',
#  'MIZORAM',
#  'NAGALAND',
#  'ODISHA',
#  'PUNJAB',
#  'RAJASTHAN',
#  'SIKKIM',
#  'TAMIL NADU',
#  'TRIPURA',
#  'UTTAR PRADESH',
#  'UTTARAKHAND',
#  'WEST BENGAL',
#  'A & N ISLANDS',
#  'CHANDIGARH',
#  'D & N HAVELI',
#  'DAMAN & DIU',
#  'DELHI',
#  'LAKSHADWEEP',
#  'PUDUCHERRY']

# %%
print(list(df["STATE/UT"].unique()))
# Out:
# ['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR', 'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA', 'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM', 'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM', 'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND', 'WEST BENGAL', 'A & N ISLANDS', 'CHANDIGARH', 'D & N HAVELI', 'DAMAN & DIU', 'DELHI', 'LAKSHADWEEP', 'PUDUCHERRY']

# %%
print(len(list(df["STATE/UT"].unique())))
# Out:
# 35

# %%
df["DISTRICT"].value_counts()
# Out:
# TOTAL              408
# G.R.P.              46
# SOUTH               37
# NORTH               37
# WEST                36
#                   ...
# RAILWAYS KMR         1
# MIDNAPUR             1
# KAWARDHA             1
# A and N ISLANDS      1
# CAR                  1
# Name: DISTRICT, Length: 808, dtype: int64

# %%
len(list(df["DISTRICT"].unique()))
# Out:
# 808

# %%
df=df.drop(list(df[df["DISTRICT"]=="total"].index))

# %%
df
# Out:
#             STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0     ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1     ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2     ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3     ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4     ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
# ...              ...            ...   ...   ...                       ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012     0                         0
# 9013     LAKSHADWEEP          TOTAL  2012     0                         0
# 9014      PUDUCHERRY       KARAIKAL  2012     6                         2
# 9015      PUDUCHERRY     PUDUCHERRY  2012     7                        14
# 9016      PUDUCHERRY          TOTAL  2012    13                        16
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
df=df.drop(list(df[df["DISTRICT"]=="delhi ut total"].index))

# %%
df
# Out:
#             STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0     ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1     ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2     ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3     ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4     ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
# ...              ...            ...   ...   ...                       ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012     0                         0
# 9013     LAKSHADWEEP          TOTAL  2012     0                         0
# 9014      PUDUCHERRY       KARAIKAL  2012     6                         2
# 9015      PUDUCHERRY     PUDUCHERRY  2012     7                        14
# 9016      PUDUCHERRY          TOTAL  2012    13                        16
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
df["DISTRICT"].unique()
# Out:
# array(['ADILABAD', 'ANANTAPUR', 'CHITTOOR', 'CUDDAPAH', 'EAST GODAVARI',
#        'GUNTAKAL RLY.', 'GUNTUR', 'HYDERABAD CITY', 'KARIMNAGAR',
#        'KHAMMAM', 'KRISHNA', 'KURNOOL', 'MAHABOOBNAGAR', 'MEDAK',
#        'NALGONDA', 'NELLORE', 'NIZAMABAD', 'PRAKASHAM', 'RANGA REDDY',
#        'SECUNDERABAD RLY.', 'SRIKAKULAM', 'VIJAYAWADA', 'VIJAYAWADA RLY.',
#        'VISAKHA RURAL', 'VISAKHAPATNAM', 'VIZIANAGARAM', 'WARANGAL',
#        'WEST GODAVARI', 'TOTAL', 'CHANGLANG', 'DIBANG VALLEY',
#        'KAMENG EAST', 'KAMENG WEST', 'LOHIT', 'PAPUM PARE', 'SIANG EAST',
#        'SIANG UPPER', 'SIANG WEST', 'SUBANSIRI LOWER', 'SUBANSIRI UPPER',
#        'TAWANG', 'TIRAP', 'BARPETA', 'BONGAIGAON', 'C.I.D.', 'CACHAR',
#        'DARRANG', 'DHEMAJI', 'DHUBRI', 'DIBRUGARH', 'G.R.P.', 'GOALPARA',
#        'GOLAGHAT', 'GUWAHATI CITY', 'HAILAKANDI', 'JORHAT', 'KAMRUP',
#        'KARBI ANGLONG', 'KARIMGANJ', 'KOKRAJHAR', 'LAKHIMPUR', 'MORIGAON',
# ...

# %%
df["Total"]=df["Rape"]+df["Kidnapping and Abduction"]+df["Dowry Deaths"]+df["Assault on women with intent to outrage her modesty"]+df["Insult to modesty of Women"]+df["Cruelty by Husband or his Relatives"]+df["Importation of Girls"]

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0  ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1  ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2  ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3  ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4  ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
# 2            14                                                112
# 3            17                                                126
# 4            12                                                109
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# ...

# %% [markdown]
# # Yearly crime rate analysis¶

# %%
plt.figure(figsize=(12,8))
df.groupby("Year")["Total"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# We can see that the crime rate has been steadily increasing as the years pass by.

# %% [markdown]
# # Percentage Distribution of each Crime based on Year

# %%
df.groupby("Year")["Rape"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df.groupby("Year")["Kidnapping and Abduction"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df.groupby("Year")["Dowry Deaths"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df.groupby("Year")["Assault on women with intent to outrage her modesty"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df.groupby("Year")["Insult to modesty of Women"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df.groupby("Year")["Insult to modesty of Women"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df.groupby("Year")["Importation of Girls"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,4,1)
df.groupby("Year")["Rape"].sum().plot(title="Rape")
plt.subplot(2,4,2)
df.groupby("Year")["Kidnapping and Abduction"].sum().plot(title="Kidnapping and Abduction")
plt.subplot(2,4,3)
df.groupby("Year")["Dowry Deaths"].sum().plot(title="Dowry Deaths")
plt.subplot(2,4,6)
df.groupby("Year")["Assault on women with intent to outrage her modesty"].sum().plot(title="Assault on women with intent to outrage her modesty")
plt.subplot(2,4,5)
df.groupby("Year")["Insult to modesty of Women"].sum().plot(title="Insult to modesty of Women")
plt.subplot(2,4,4)
df.groupby("Year")["Cruelty by Husband or his Relatives"].sum().plot(title="Cruelty by Husband or his Relatives")
plt.subplot(2,4,7)
df.groupby("Year")["Importation of Girls"].sum().plot(title="Importation of Girls")
plt.subplot(2,4,8)
df.groupby("Year")["Total"].sum().plot(title="Total No. of Crimes")
# Out:
# <AxesSubplot:title={'center':'Total No. of Crimes'}, xlabel='Year'>

# %%
crimes=['Rape','Kidnapping and Abduction','Dowry Deaths',
        'Assault on women with intent to outrage her modesty',
        'Insult to modesty of Women','Cruelty by Husband or his Relatives',
        'Importation of Girls']

df1=pd.DataFrame()
for i in crimes:
    df_crime=df.groupby(['Year'])[i].sum()
    df1[i]=df_crime
df1
# Out:
#        Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2001  32150                     29290         13702
# 2002  32746                     29012         13644
# 2003  31694                     26592         12416
# 2004  36466                     31156         14052
# 2005  36718                     31500         13574
# 2006  38696                     34828         15236
# 2007  41474                     40832         16186
# 2008  42934                     45878         16344
# 2009  42794                     51482         16766
# 2010  44344                     59590         16782
# 2011  48412                     71130         17236
# 2012  49846                     76524         16466
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                              68248
# 2002                                              67886
# 2003                                              65878
# ...

# %%
df1.plot.bar()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# Percentage Distribution of crime type

# %%
a=[]
for i in crimes:
    a.append(df1[i].sum())
a.sort()
plt.figure(figsize=(10,15))
plt.pie(a,labels=crimes,autopct='%1.2f%%')
plt.tight_layout()

# %%
df1.T
# Out:
# Year                                                 2001   2002    2003  \
# Rape                                                32150  32746   31694
# Kidnapping and Abduction                            29290  29012   26592
# Dowry Deaths                                        13702  13644   12416
# Assault on women with intent to outrage her mod...  68248  67886   65878
# Insult to modesty of Women                          19492  20310   24650
# Cruelty by Husband or his Relatives                 98340  98474  101406
# Importation of Girls                                  228    152      92
#
# Year                                                  2004    2005    2006  \
# Rape                                                 36466   36718   38696
# Kidnapping and Abduction                             31156   31500   34828
# Dowry Deaths                                         14052   13574   15236
# Assault on women with intent to outrage her mod...   69134   68350   73234
# ...

# %% [markdown]
# # State / UT wise Analysis of Crime

# %%
plt.figure(figsize=(17,7))
df.groupby("STATE/UT")["Total"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='STATE/UT'>

# %% [markdown]
# We can observe that Uttar Pradesh records the highest crimes against women followed by Madhya Pradesh and Maharashtra.

# %%
df1=pd.DataFrame()
for i in crimes:
    dfcrime=df.groupby(['STATE/UT'])[i].sum()
    df1[i]=dfcrime
df1
# Out:
#                     Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# A & N ISLANDS        218                       154            12
# ANDHRA PRADESH     26958                     29872         12430
# ARUNACHAL PRADESH   1000                      1116             4
# ASSAM              32356                     45840          2552
# BIHAR              26248                     38778         27096
# CHANDIGARH           562                      1068            84
# CHHATTISGARH       23676                      5260          2284
# D & N HAVELI         112                       188             2
# DAMAN & DIU           40                        30             6
# DELHI              12848                     31300          3164
# GOA                  700                       328            38
# GUJARAT             8498                     25836          1004
# HARYANA            12820                     12258          6260
# ...

# %%
df1.plot.line()
# Out:
# <AxesSubplot:xlabel='STATE/UT'>

# %%
df1[i]=dfcrime
df1["Total"]=df1.sum(axis=1)
df1=df1.sort_values(by="Total",ascending=False)
df1.reset_index()
df1
# Out:
#                     Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# ANDHRA PRADESH     26958                     29872         12430
# UTTAR PRADESH      38116                     95180         47648
# WEST BENGAL        41574                     43546         10344
# MADHYA PRADESH     72174                     18486         18072
# RAJASTHAN          31596                     49342         10132
# MAHARASHTRA        35972                     21706          8498
# ASSAM              32356                     45840          2552
# KERALA             14894                      3796           602
# GUJARAT             8498                     25836          1004
# BIHAR              26248                     38778         27096
# ODISHA             22860                     16582          9110
# TAMIL NADU         13904                     24872          4634
# KARNATAKA          10348                     10630          5836
# ...

# %% [markdown]
# #          TOP 3 CRIMES

# %%
df1.head(5)
# Out:
#                  Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# ANDHRA PRADESH  26958                     29872         12430
# UTTAR PRADESH   38116                     95180         47648
# WEST BENGAL     41574                     43546         10344
# MADHYA PRADESH  72174                     18486         18072
# RAJASTHAN       31596                     49342         10132
#
#                 Assault on women with intent to outrage her modesty  \
# STATE/UT
# ANDHRA PRADESH                                             103998
# UTTAR PRADESH                                               59396
# WEST BENGAL                                                 45742
# MADHYA PRADESH                                             159756
# RAJASTHAN                                                   61706
#
#                 Insult to modesty of Women  \
# STATE/UT
# ANDHRA PRADESH                       72262
# UTTAR PRADESH                        53022
# ...

# %% [markdown]
#                        low numb crimes

# %%
df1.tail(3)
# Out:
#               Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# D & N HAVELI   112                       188             2
# DAMAN & DIU     40                        30             6
# LAKSHADWEEP     14                         2             0
#
#               Assault on women with intent to outrage her modesty  \
# STATE/UT
# D & N HAVELI                                                100
# DAMAN & DIU                                                  30
# LAKSHADWEEP                                                  10
#
#               Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# STATE/UT
# D & N HAVELI                           8                                   76
# DAMAN & DIU                            4                                   70
# LAKSHADWEEP                            0                                   14
#
#               Importation of Girls  Total
# STATE/UT
# D & N HAVELI                     0    486
# ...

# %% [markdown]
# #                 RAPES

# %%
rape=df1.sort_values(by="Rape",ascending=False)
rape1=rape.head(5)
plt.figure(figsize=(10,5))
plt.pie(rape1.Rape,labels=rape1.index,autopct='%1.2f%%')
plt.title("Top 5 States by No. of Cases on Rape")
plt.tight_layout()

# %% [markdown]
# # KIDNAPPING

# %%
kidnap=df1.sort_values(by="Kidnapping and Abduction",ascending=False)
kid=kidnap.head(5)
plt.figure(figsize=(10,5))
plt.pie(kid['Kidnapping and Abduction'],labels=kid.index,autopct='%1.2f%%')
plt.title("Top 5 States by No. of Cases on kidnap and abduction")
plt.tight_layout()

# %% [markdown]
# #                 Dowry Deaths

# %%
dowry=df1.sort_values(by="Dowry Deaths",ascending=False)
dow=dowry.head(5)
plt.figure(figsize=(10,5))
plt.pie(dow['Dowry Deaths'],labels=dow.index,autopct='%1.2f%%')
plt.title(" Cases   Dowry Deaths")
plt.tight_layout()

# %% [markdown]
# #                      Assault on women with intent to outrage her modesty

# %%
assault=df1.sort_values(by="Assault on women with intent to outrage her modesty",ascending=False)
ass=assault.head(5)
plt.figure(figsize=(10,5))
plt.pie(ass['Assault on women with intent to outrage her modesty'],labels=ass.index,autopct='%1.2f%%')
plt.title("Assault on women with intent to outrage her modesty")
plt.tight_layout()

# %% [markdown]
# #                        Insult to modesty of Women

# %%
modesty=df1.sort_values(by="Insult to modesty of Women",ascending=False)
mod=modesty.head(5)
plt.figure(figsize=(10,5))
plt.pie(mod['Insult to modesty of Women'],labels=mod.index,autopct='%1.2f%%')
plt.title("CASE  INsult to modesty")
plt.tight_layout()

# %% [markdown]
# #              Cruelty by Husband or his Relatives

# %%
crue=df1.sort_values(by="Cruelty by Husband or his Relatives",ascending=False)
c=crue.head(5)
plt.figure(figsize=(10,5))
plt.pie(c['Cruelty by Husband or his Relatives'],labels=c.index,autopct='%1.2f%%')
plt.title("CASE Cruelty by Husband or his Relatives ")
plt.tight_layout()

# %% [markdown]
# #     Importation of Girls

# %%
imprt=df1.sort_values(by="Importation of Girls",ascending=False)
im=imprt.head(5)
plt.figure(figsize=(10,5))
plt.pie(im['Importation of Girls'],labels=im.index,autopct='%1.2f%%')
plt.title("  CASE Importation of Girls")
plt.tight_layout()

# %% [markdown]
# #   ANALYSIS

# %%
df_up=df1.loc[df1.index=="UTTAR PRADESH"]
dfupT=df_up.T.drop("Total")
dfupT
# Out:
# STATE/UT                                            UTTAR PRADESH
# Rape                                                        38116
# Kidnapping and Abduction                                    95180
# Dowry Deaths                                                47648
# Assault on women with intent to outrage her mod...          59396
# Insult to modesty of Women                                  53022
# Cruelty by Husband or his Relatives                        155234
# Importation of Girls                                            6

# %%
dfupT.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df=df1.loc[df1.index=="ANDHRA PRADESH"]
dfupT=df.T.drop("Total")
dfupT
# Out:
# STATE/UT                                            ANDHRA PRADESH
# Rape                                                         26958
# Kidnapping and Abduction                                     29872
# Dowry Deaths                                                 12430
# Assault on women with intent to outrage her mod...          103998
# Insult to modesty of Women                                   72262
# Cruelty by Husband or his Relatives                         238014
# Importation of Girls                                            34

# %%
df=df1.loc[df1.index=="WEST BENGAL"]
df2=df.T.drop("Total")
df2
# Out:
# STATE/UT                                            WEST BENGAL
# Rape                                                      41574
# Kidnapping and Abduction                                  43546
# Dowry Deaths                                              10344
# Assault on women with intent to outrage her mod...        45742
# Insult to modesty of Women                                 3108
# Cruelty by Husband or his Relatives                      261336
# Importation of Girls                                        228

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df=df1.loc[df1.index=="MADHYA PRADESH"]
df2=df.T.drop("Total")
df2
# Out:
# STATE/UT                                            MADHYA PRADESH
# Rape                                                         72174
# Kidnapping and Abduction                                     18486
# Dowry Deaths                                                 18072
# Assault on women with intent to outrage her mod...          159756
# Insult to modesty of Women                                   18634
# Cruelty by Husband or his Relatives                          79938
# Importation of Girls                                           120

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df=df1.loc[df1.index=="RAJASTHAN"]
df2=df.T.drop("Total")
df2
# Out:
# STATE/UT                                            RAJASTHAN
# Rape                                                    31596
# Kidnapping and Abduction                                49342
# Dowry Deaths                                            10132
# Assault on women with intent to outrage her mod...      61706
# Insult to modesty of Women                                708
# Cruelty by Husband or his Relatives                    200202
# Importation of Girls                                       12

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>
